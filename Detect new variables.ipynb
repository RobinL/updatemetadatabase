# %% [markdown]
# This script detects new variables in the datasets which have been sent through by ORS and adds them into the metadatbase
# <style>
# table.dataframe {
# font-size:60%;
# line-height:60%;
# padding:1px;
# margin:1px;
# }
# </style>

# %%
#Make a copy of the database so if we mess it up it doesn't matter
import shutil
import os

src =r"bu/metadatabase.mdb"
dst = os.path.join(os.getcwd(),r"metadatabase.mdb")
shutil.copy(src, dst)
# Out:
# 'C:\\Users\\Robin-Laptop\\Documents\\IPython Notebooks\\updatemetadatabase\\metadatabase.mdb'

# %%
#Connect to the metadatabase using pyodbc
import os
import pyodbc
import re
dst = os.path.join(os.getcwd(),r"metadatabase.mdb")
MDB = dst
DRV = '{Microsoft Access Driver (*.mdb, *.accdb)}'

con = pyodbc.connect('DRIVER=%s;DBQ=%s;' % (DRV,MDB))
cur = con.cursor()

# %%
import pandas as pd
import pandas.io.sql as sql 
pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', 500)

# %%
#Import the list variables in the new datasets
src =r"variablenamesandformats/List of variables in forms.xls"
olddf = pd.read_excel(src,"old _forms",header=1)
newdf = pd.read_excel(src,"new_forms",header=1)

# %%
#filter from olddf any variables which are in newdf.  We want descriptions from the new database to override descriptions from the old db

not_in = -olddf['Variable'].isin(newdf["Variable"])
olddf = olddf[not_in]

# %%
#concatenate the two datasets
alldf = pd.concat([olddf, newdf])
distinctnewvars = alldf.groupby(["Variable","Label"]).size().reset_index()
distinctnewvars =distinctnewvars.rename(columns= {0: "shouldbe1"})

# %%
#Create a dataframe of the variables in the meta database
variables = sql.read_frame('select * from tblVariables', con)

# %%
#Find variables which are in distinct new variables but are not in the metadatabase
not_in = -distinctnewvars['Variable'].isin(variables["OriginalORSName"])
distinctnewvars = distinctnewvars[not_in]

# %%
#Now we have a list of the distinct new variables

#Figure out there are groups of variables in the list of new variables
distinctnewvars["LabelNoCode"] = distinctnewvars["Label"].str.match("([^#]+)").str.get(0).str.strip()

# %%
groups = distinctnewvars.groupby("LabelNoCode").size().reset_index()
groups =groups.rename(columns= {0: "sizeofgroup"})
groups
# Out:
#                                                                                      LabelNoCode  sizeofgroup
# 0                                                                    EPP Extension Period (Days)            1
# 1                                                                        Extended Custodial Term            1
# 2                                                                 Extended Custodial Term (Days)            1
# 3                                                            Extended Custodial Term Time period            1
# 4                                                                      Extended Extension Period            1
# 5                                                          Extended Extension Period Time period            1
# 6                                                                                        Form ID            1
# 7                                                                                  Highest level            1
# 8                             Q2B2C: Requirements of Suspended Sentence Order or Community Order           39
# 9                                                                       Q3C: Offence seriousness            5
# 10  Q3CAC: Factors indicating higher culpability Offence motivated by/demonstrating hostility to            4
# 11                                             Sentence outcome (for the PRINCIPAL OFFENCE ONLY)            1
# 12                                                                               Type of Offence            1
# 13                                                                               Type of offence            3
# 14                                          Was a guilty plea entered for the principal offence?            1
# 15                                                        Was guilt indicated at police station?            1
# 16                                                                Where was guilty plea entered?            1

# %%
#Tomorrow join these back on to the new variables table and attempt to detect the prefix and suffix

#The difficulty is going to be detecting whether each variable needs a new description grou
#I guess you just look in the table to see whether the prefix plus basename exists.  If it does, you don't need a new description group
#you just put the variable in and use its current descirption group

distinctnewvarswithgroups = distinctnewvars.merge(groups, left_on = "LabelNoCode", right_on = "LabelNoCode", how="left")

# %%
#need to create
#suffix
#suffixcode
#prefix
#basename
#revisionnum
import re
def revisionnum(x):
    r = re.search("_\d$",x)
    if r:
        return r.group(0)
    else:
        return ""

distinctnewvarswithgroups["RevisionNum"] = distinctnewvarswithgroups["Variable"].apply(revisionnum)

# %%
#Prefix

#Get list of prefixes
prefixes = sql.read_frame('select * from tblPrefix', con)
plist =  prefixes["ORSPrefix"].tolist()
plist = list(filter(None, plist))
reexp = "|".join(plist)
reexp = "(" + reexp + ")(.+)"

def prefix(x):
    
    r = re.match(reexp,x)
    if r:
        prefix = r.group(1)
    else:
        prefix = ""
        
    return prefix

distinctnewvarswithgroups["prefix"] = distinctnewvarswithgroups["Variable"].apply(prefix)

# %%
from functools import partial
def basenamecandidate(row):
   
    x = row["Variable"]
    #Remove revisionnum if it exists
    r = re.search("(.+)_\d$",x)
    if r:
        x = r.group(1)
    
    #Remove prefix if it exists
    r = re.match(reexp,x)
    if r:
        x = r.group(2)
  
    
    return x

distinctnewvarswithgroups["basenamecandidate"] = distinctnewvarswithgroups.apply(basenamecandidate, axis=1)

def grouplen(minus,row):
    #Find out what the base name 'would be' if there was a suffix, and check whether we have a group
    #Get the max length of the current basename+suffix string.  Take two off it.  Then truncate this string if need be
    thisgroup = distinctnewvarswithgroups[distinctnewvarswithgroups["LabelNoCode"]==row["LabelNoCode"]]
    maxlen = thisgroup["basenamecandidate"].str.len().max()
    maxlenofbase = maxlen-minus
    x = row["basenamecandidate"][:maxlenofbase]
    x = row["prefix"] + x + row["RevisionNum"]
    return x



distinctnewvarswithgroups["grouplen1txt"] = distinctnewvarswithgroups.apply(partial(grouplen,1), axis=1)
distinctnewvarswithgroups["grouplen2txt"] = distinctnewvarswithgroups.apply(partial(grouplen,2), axis=1)

def isitagroup(field,row):
    thisgroup = distinctnewvarswithgroups[distinctnewvarswithgroups["LabelNoCode"]==row["LabelNoCode"]]
    a = thisgroup.groupby(field).size().reset_index()
    if len(a.index) ==1:
        if a[0].min()>1:
            return True
        else:
            return False
    else:
        return False

    

distinctnewvarswithgroups["grouplen1"] = distinctnewvarswithgroups.apply(partial(isitagroup,"grouplen1txt"), axis=1)
distinctnewvarswithgroups["grouplen2"] = distinctnewvarswithgroups.apply(partial(isitagroup,"grouplen2txt"), axis=1)

# %%
def getsuffix(row):
   
    x = row["Variable"]
    #Remove revisionnum if it exists
    r = re.search("(.+)_\d$",x)
    if r:
        x = r.group(1)
    
    #Remove prefix if it exists
    r = re.match(reexp,x)
    if r:
        x = r.group(2)
        
    if row["grouplen1"]:
        return x[-1:]
    elif row["grouplen2"]:
        thisgroup = distinctnewvarswithgroups[distinctnewvarswithgroups["LabelNoCode"]==row["LabelNoCode"]]
        maxlen = thisgroup["Variable"].str.len().max()
        if len(row["Variable"]) < maxlen:
            return x[-1:]
        else:
            return x[-2:]
    else:
        return ""
  
    return x

distinctnewvarswithgroups["suffix"] = distinctnewvarswithgroups.apply(getsuffix, axis=1)

# %%
#Now we just need to get the basename, - anything that isn't the prefix, the suffix or the revisionnum
def getbasename(row):
    lp =len(row["prefix"])
    ls =len(row["suffix"]) + len(row["RevisionNum"])
    if ls == 0:
         return row["Variable"][lp:]
    else:
        return row["Variable"][lp:-ls]

distinctnewvarswithgroups["basename"] = distinctnewvarswithgroups.apply(getbasename, axis=1)

#Check that it's worked
distinctnewvarswithgroups["vcheck"] = distinctnewvarswithgroups["prefix"]\
+ distinctnewvarswithgroups["basename"]\
+ distinctnewvarswithgroups["suffix"]\
+ distinctnewvarswithgroups["RevisionNum"]

#print(distinctnewvarswithgroups["vcheck"] == distinctnewvarswithgroups["Variable"])
distinctnewvarswithgroups[["Variable","basename","prefix","RevisionNum","suffix","LabelNoCode"]]
# Out:
#                       Variable                    basename prefix RevisionNum suffix                                                                                   LabelNoCode
# 0                     APOQ1A_1                         Q1A    APO          _1                                                                                      Type of offence
# 1                     OFFQ1A_1                         Q1A    OFF          _1                                                                                      Type of offence
# 2   SINGLE_OR_MULTIPLE_OFFENCE  SINGLE_OR_MULTIPLE_OFFENCE                                                                                                         Type of offence
# 3                   APOQ3CAA_1                        Q3CA    APO          _1      A  Q3CAC: Factors indicating higher culpability Offence motivated by/demonstrating hostility to
# 4                   APOQ3CAB_1                        Q3CA    APO          _1      B  Q3CAC: Factors indicating higher culpability Offence motivated by/demonstrating hostility to
# 5                   APOQ3CAC_1                        Q3CA    APO          _1      C  Q3CAC: Factors indicating higher culpability Offence motivated by/demonstrating hostility to
# 6                   APOQ3CAE_1                        Q3CA    APO          _1      E  Q3CAC: Factors indicating higher culpability Offence motivated by/demonstrating hostility to
# 7                    BARCODETX                   BARCODETX                                                                                                                 Form ID
# 8              Highest_level_1               Highest_level                 _1                                                                                        Highest level
# 9                INDICTPLEAA_1                 INDICTPLEAA                 _1                                                               Was guilt indicated at police station?
# 10               INDICTPLEAB_1                 INDICTPLEAB                 _1                                                                       Where was guilty plea entered?
# 11        INDICTPLEAWASENTERED        INDICTPLEAWASENTERED                                                                    Was a guilty plea entered for the principal offence?
# 12            Q2ACPERIODTYPE_1              Q2ACPERIODTYPE                 _1                                                                  Extended Custodial Term Time period
# 13                    Q2ACTX_1                      Q2ACTX                 _1                                                                              Extended Custodial Term
# 14                 Q2AC_DAYS_1                   Q2AC_DAYS                 _1                                                                       Extended Custodial Term (Days)
# 15            Q2ADPERIODTYPE_1              Q2ADPERIODTYPE                 _1                                                                Extended Extension Period Time period
# 16                    Q2ADTX_1                      Q2ADTX                 _1                                                                            Extended Extension Period
# 17                 Q2AD_DAYS_1                   Q2AD_DAYS                 _1                                                                          EPP Extension Period (Days)
# 18                       Q2A_1                         Q2A                 _1                                                    Sentence outcome (for the PRINCIPAL OFFENCE ONLY)
# 19                    Q2B2AA_1                        Q2B2                 _1     AA                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 20                    Q2B2AB_1                        Q2B2                 _1     AB                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 21                    Q2B2AC_1                        Q2B2                 _1     AC                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 22                    Q2B2AD_1                        Q2B2                 _1     AD                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 23                    Q2B2AF_1                        Q2B2                 _1     AF                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 24                    Q2B2AI_1                        Q2B2                 _1     AI                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 25                    Q2B2AK_1                        Q2B2                 _1     AK                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 26                    Q2B2AL_1                        Q2B2                 _1     AL                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 27                    Q2B2AM_1                        Q2B2                 _1     AM                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 28                    Q2B2AN_1                        Q2B2                 _1     AN                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 29                    Q2B2AO_1                        Q2B2                 _1     AO                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 30                    Q2B2AP_1                        Q2B2                 _1     AP                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 31                    Q2B2AQ_1                        Q2B2                 _1     AQ                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 32                    Q2B2AR_1                        Q2B2                 _1     AR                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 33                     Q2B2A_1                        Q2B2                 _1      A                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 34                     Q2B2B_1                        Q2B2                 _1      B                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 35                    Q2B2CL_1                        Q2B2                 _1     CL                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 36                     Q2B2C_1                        Q2B2                 _1      C                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 37                     Q2B2D_1                        Q2B2                 _1      D                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 38                     Q2B2E_1                        Q2B2                 _1      E                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 39                     Q2B2F_1                        Q2B2                 _1      F                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 40                     Q2B2G_1                        Q2B2                 _1      G                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 41                     Q2B2H_1                        Q2B2                 _1      H                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 42                     Q2B2I_1                        Q2B2                 _1      I                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 43                     Q2B2J_1                        Q2B2                 _1      J                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 44                     Q2B2K_1                        Q2B2                 _1      K                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 45                     Q2B2L_1                        Q2B2                 _1      L                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 46                     Q2B2M_1                        Q2B2                 _1      M                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 47                     Q2B2O_1                        Q2B2                 _1      O                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 48                     Q2B2P_1                        Q2B2                 _1      P                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 49                     Q2B2Q_1                        Q2B2                 _1      Q                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 50                     Q2B2R_1                        Q2B2                 _1      R                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 51                     Q2B2S_1                        Q2B2                 _1      S                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 52                     Q2B2T_1                        Q2B2                 _1      T                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 53                     Q2B2U_1                        Q2B2                 _1      U                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 54                     Q2B2V_1                        Q2B2                 _1      V                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 55                     Q2B2X_1                        Q2B2                 _1      X                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 56                     Q2B2Y_1                        Q2B2                 _1      Y                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 57                     Q2B2Z_1                        Q2B2                 _1      Z                            Q2B2C: Requirements of Suspended Sentence Order or Community Order
# 58                    ROBQ3A_1                          Q3    ROB          _1      A                                                                      Q3C: Offence seriousness
# 59                    ROBQ3B_1                          Q3    ROB          _1      B                                                                      Q3C: Offence seriousness
# 60                    ROBQ3C_1                          Q3    ROB          _1      C                                                                      Q3C: Offence seriousness
# 61                    ROBQ3D_1                          Q3    ROB          _1      D                                                                      Q3C: Offence seriousness
# 62                    ROBQ3E_1                          Q3    ROB          _1      E                                                                      Q3C: Offence seriousness
# 63           Type_of_Offence_1             Type_of_Offence                 _1                                                                                      Type of Offence

# %%
#Now these need to be added to the database!!
# SQLUpdateVariablesTable = """
# Insert into tblVariables (originalorsname, basename,)
# values (?,?,?)
# """


SQLFindPrefix = """
select id, finalprefix from 
tblPrefix
where ORSPrefix = ?
"""

SQLFindDescCode = """
select groupdescriptionid from 
tblVariables
where
basename = ? and prefixid = ? and revisionnum = ?
"""

SQLInsertDescription = """
insert into tblDescriptiongroups 
(description)
values (?)
"""

SQLInsertVariable = """
insert into tblVariables 
(originalORSname, basename, finalname, prefixid, suffix, suffixcode, revisionnum, groupdescriptionid, inORSRawDataset)
values (?,?,?,?,?,?,?,?,?)
"""

SQLGetSuffix = """
select suffixcode
from tblVariables
where suffix = ?
"""

for row in distinctnewvarswithgroups.iterrows():
    row = row[1]
    basename = row["basename"]
    prefix = row["prefix"]
    RevisionNum = row["RevisionNum"]
    variable = row["Variable"]
    suffix = row["suffix"]
    description = row["LabelNoCode"]
    
    if suffix:
        suffixget = cur.execute(SQLGetSuffix,(suffix))
        suffixcode = suffixget.fetchone()[0]
    else:
        suffixcode = None
    
    #Figure out the relevant prefix ID and get the finalprefix
    records = cur.execute(SQLFindPrefix, (prefix))
    idrecord = records.fetchone()
    if idrecord:
        prefixid = str(idrecord[0])
        finalprefix = idrecord[1]
    else:
        prefixid = "14"
        finalprefix = ""
     
    #If this basename, prefix and revision num combo already in dataset, figure out the description group
    records = cur.execute(SQLFindDescCode, (basename, prefixid, RevisionNum))
  
    
    iddesc = records.fetchone()
    if iddesc:
        descid = iddesc[0]
    else:
        descid = None
   

    #Otherwise add this description as a description group
    if descid == None:
        cur.execute(SQLInsertDescription,(description))
        cur.commit()
        descid = cur.execute("SELECT @@Identity").fetchall()[0][0]
        
    
    
    if prefixid:
        prefixid = str(prefixid)
    else:
        prefixid = "14"
        
    finalname = finalprefix + basename + suffix + RevisionNum
    descid = int(descid)
    
   
    #Write the new finalname and add to db   
    
    
    cur.execute(SQLInsertVariable, (variable, basename, finalname,str(prefixid), suffix,str(suffixcode), RevisionNum,str(descid), True))
    cur.commit()

# %%
records = cur.execute(SQLFindDescCode, ("Q2B2", "14", "_1"))
iddesc = records.fetchone()
if iddesc:
    descid = iddesc[0]
else:
    descid = None

# %%
descid
# Out:
# 243
