# %% [markdown]
# Aim:
#
# Some descriptions in the meta database are currently linked to many variables
#
# This is desirable in the case where we have a 'group of variables' (usually 94) with various suffixes
#
# However, in all other cases it is undesirable because a change to a single description will affect the description for multiple variables.  The edit may only be relevant to one of these variables.
#
# This script detects the one to many relations between descriptions and variables and eliminates them
#
# It also detects and deletes descriptions which are not connected to any variables and are therefore obsolete

# %% [markdown]
# Each unique combnation of prefix and basename wants a single unique description
#
# (1)  Check that there aren't combiantions of prefix and basename with more than one description
#
# (2)  Make a table of unique combinations of prefix and basename and description
#
# (3)  Delete all data in tblDescriptionGroups
#
# (3)  GO through each unique combination of prefix and basename:
#
#   (a)Delete current descriptionid
#
#   (b)Add new description to
#
#   (c)Update tblVariables

# %%
#Make a copy of the database so if we mess it up it doesn't matter
import shutil

src =r"C:\Users\Office Samsung\Documents\IPython Notebooks\BU\metadatabase.mdb"
dst = r"C:\Users\Office Samsung\Documents\IPython Notebooks\metadatabase.mdb"

shutil.copy(src, dst)

# %%
#pyodbc will allow us to connect to a .mdb databse
import pyodbc

# %%
MDB = dst
DRV = '{Microsoft Access Driver (*.mdb, *.accdb)}'

con = pyodbc.connect('DRIVER=%s;DBQ=%s;' % (DRV,MDB))
cur = con.cursor()

# %%
#Get rid of any 'orphaned' descriptions - i.e. ones which aren't linked to any variables.  

SQL1 = """Select id from tblDescriptionGroups 
where id not in 
(select GroupDescriptionID 
from tblVariables 
where GroupDescriptionID is not null)
"""

records = cur.execute(SQL1).fetchall()
print records[0]

SQL2 = """
delete from tblDescriptiongroups 
where id not in 
(select GroupDescriptionID 
from tblVariables 
where GroupDescriptionID is not null)
"""

cur.execute(SQL2)
# Out:
# (98, )

# %%
import pandas as pd
from pandas import DataFrame, Series
import pandas.io.sql as sql

pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 500)

variables = sql.read_frame('select * from tblVariables', con)
descriptions = sql.read_frame('select * from tblDescriptionGroups', con)

# %%
#Make a table of unique combinations of prefix and basename and description
variableswithdescriptions = variables.merge(descriptions, left_on="GroupDescriptionID", right_on="ID", how="left")
variableswithdescriptions.head()
# Out:
#    ID_x OriginalORSName        BaseName       FinalName  PrefixID Suffix  \
# 0     1       unique_id       unique_id       unique_id        14   None
# 1     2          UNIQUE          UNIQUE          UNIQUE        14   None
# 2     3          ISSUED          ISSUED          ISSUED        14   None
# 3     4  SENTENCEDATETX  SENTENCEDATETX  SENTENCEDATETX        14   None
# 4     5      CREST_IDTX      CREST_IDTX      CREST_IDTX        14   None
#
#   SuffixCode ORSDescription  GroupDescriptionID  \
# 0       None           None                   1
# 1       None        (blank)                   2
# 2       None     Issue date                   3
# 3       None  Sentence date                   4
# 4       None  Crest case ID                   5
#
#                                               Issues InORSRawDataset  ID_y  \
# 0  The unique IDs provided to us (in the UNIQUE f...           False     1
# 1  The unique IDs provided to us aren't always un...            True     2
# 2                                               None            True     3
# 3                                               None            True     4
# 4                                               None            True     5
#
#                                          Description
# 0  Unique_id is a unique identifier for this reco...
# 1          UNIQUE as provided by ORS - Not unique!!!
# 2                                         Issue date
# 3                                      Sentence date
# 4                                      Crest case ID

# %%
#Check that there aren't combiantions of prefix and basename with more than one description
prefixbasegroups = variableswithdescriptions.groupby(['PrefixID', "BaseName", "GroupDescriptionID", "Description"]).size()
prefixbasegroups = prefixbasegroups.reset_index()
prefixbasegroups.rename(columns={0: "numvars"}, inplace=True)
gdid = prefixbasegroups.groupby(["GroupDescriptionID"]).size()
gdid = gdid.reset_index().rename(columns={0: "sizenum"})
gdid[gdid["sizenum"]>1].head()
# Out:
#     GroupDescriptionID  sizenum
# 10                  11        2
# 39                  40        2
# 42                  43        2
# 69                  70        3
# 70                  71        2

# %%
#Fix the descriptions
#Iterate through 
prefixbasegroups.head()
# Out:
#    PrefixID BaseName  GroupDescriptionID                                        Description  numvars
# 0         2      Q1A                 161                                    Type of offence        1
# 1         2    Q1ATX                 185                                    Type of offence        1
# 2         2      Q1X                 162                                   Level of offence        1
# 3         2       Q3                 163                          Q3C: Offence seriousness        94
# 4         2      Q4A                 164  Previous convictions, Did the offender have an...        1

# %%
#Just delete everything from the descriptions table and use the above table to rewrite it!!!

# %%
GetRidOfLinksSQL = """
UPDATE tblVariables
SET groupdescriptionid = Null
"""
cur.execute(GetRidOfLinksSQL)
cur.commit()

DeleteSQL = """
delete from tblDescriptionGroups
"""
cur.execute(DeleteSQL)
cur.commit()

# %%
SQLUpdateDescriptionsTable = """
Insert into tblDescriptionGroups
(Description)
VALUES
(?) """



    
SQLUpdateListingsTable = """
UPDATE tblVariables
SET groupdescriptionid = ?
where PrefixID	= ? and BaseName = ?
"""

for thisRow in prefixbasegroups.iterrows():
    cur.execute(SQLUpdateDescriptionsTable,(thisRow[1]["Description"],))
    idOfRecordJustAdded = cur.execute("SELECT @@Identity").fetchall()[0][0]
    print str(idOfRecordJustAdded) + "|" + str(thisRow[1]["PrefixID"]) + "|" +  thisRow[1]["BaseName"] 

    cur.execute(SQLUpdateListingsTable,(idOfRecordJustAdded,str(thisRow[1]["PrefixID"]),thisRow[1]["BaseName"]))

cur.commit()
# Out:
# 227|2|Q1A
# 228|2|Q1ATX
# 229|2|Q1X
# 230|2|Q3
# 231|2|Q4A
# 232|2|Q4B
# 233|2|Q5
# 234|2|Q5TX
# 235|2|Q6
# 236|2|Q6TX
# 237|3|Q1A
# 238|3|Q1APO
# 239|3|Q1ATX
# 240|3|Q1X
# 241|3|Q3A
# 242|3|Q3B
# 243|3|Q3CA
# 244|3|Q3CB
# 245|3|Q3D
# 246|3|Q4
# 247|3|Q5AA
# 248|3|Q5AB
# 249|3|Q5AC
# 250|3|Q5ACTX
# 251|3|Q5B
# 252|3|Q5BTX
# 253|4|Q1A
# 254|4|Q1ATX
# 255|4|Q1X
# 256|4|Q3A
# 257|4|Q3B
# 258|4|Q3C
# 259|4|Q3D
# 260|4|Q4
# 261|4|Q5AA
# 262|4|Q5AB
# 263|4|Q5AC
# 264|4|Q5ACTX
# 265|4|Q5B
# 266|4|Q5BTX
# 267|5|Q1A
# 268|5|Q1ATX
# 269|5|Q1X
# 270|5|Q3
# 271|5|Q4A
# 272|5|Q4B
# 273|5|Q5
# 274|5|Q5TX
# 275|5|Q6
# 276|5|Q6TX
# 277|6|Q1A
# 278|6|Q1ATX
# 279|6|Q1DRG
# 280|6|Q1X
# 281|6|Q3A
# 282|6|Q3B
# 283|6|Q3C
# 284|6|Q3D
# 285|6|Q3E
# 286|6|Q4AA
# 287|6|Q4AB
# 288|6|Q4AC
# 289|6|Q4ACTX
# 290|6|Q4B
# 291|6|Q4BTX
# 292|7|Q1A
# 293|7|Q1ATX
# 294|7|Q1X
# 295|7|Q3
# 296|7|Q4A
# 297|7|Q4B
# 298|7|Q5
# 299|7|Q5TX
# 300|7|Q6
# 301|7|Q6TX
# 302|8|Q1A
# 303|8|Q1ATX
# 304|8|Q1X
# 305|8|Q3
# 306|8|Q4A
# 307|8|Q4B
# 308|8|Q5
# 309|8|Q5TX
# 310|8|Q6
# 311|8|Q6TX
# 312|9|Q1A
# 313|9|Q1ATX
# 314|9|Q1ROB
# 315|9|Q1ROBTX
# 316|9|Q1X
# 317|9|Q3
# 318|9|Q4A
# 319|9|Q4B
# 320|9|Q5
# 321|9|Q5TX
# 322|9|Q6
# 323|9|Q6TX
# 324|10|Q1A
# 325|10|Q1ATX
# 326|10|Q1X
# 327|10|Q3
# 328|10|Q4A
# 329|10|Q4B
# 330|10|Q5
# 331|10|Q5TX
# 332|10|Q6
# 333|10|Q6TX
# 334|11|Q1A
# 335|11|Q1ATX
# 336|11|Q1X
# 337|11|Q3
# 338|11|Q4A
# 339|11|Q4B
# 340|11|Q5
# 341|11|Q5TX
# 342|11|Q6
# 343|11|Q6
# 344|11|Q6TX
# 345|12|Q1
# 346|12|Q1A
# 347|12|Q1APO
# 348|12|Q3
# 349|12|Q4A
# 350|12|Q4B
# 351|12|Q5
# 352|12|Q6
# 353|14|ADDFACT
# 354|14|ADDFACTTX
# 355|14|Additional_Factors
# 356|14|Agg_number
# 357|14|Aggravating_Factors
# 358|14|Amount1
# 359|14|Amount1_inc_IPPs
# 360|14|CASEPROCESS
# 361|14|CC_CENTRE
# 362|14|COMPANYNAMETX
# 363|14|CREST_IDTX
# 364|14|DOBTX
# 365|14|FORENAMETX
# 366|14|FORM
# 367|14|FORMRECEIVEDDATETX
# 368|14|Guilty_plea_factor
# 369|14|Highest_level
# 370|14|INDICTPLEAA
# 371|14|INDICTPLEAA_1
# 372|14|INDICTPLEAB
# 373|14|INDICTPLEAB_1
# 374|14|INDICTPLEAC
# 375|14|INDICTPLEAC_1
# 376|14|INDICTPLEAD
# 377|14|INDICTPLEAD_1
# 378|14|INDICTPLEATX
# 379|14|ISSUED
# 380|14|Miti_number
# 381|14|Mitigating_Factors
# 382|14|OFFENDERGENDER
# 383|14|Plea
# 384|14|Q2A
# 385|14|Q2AAPERIODTYPE
# 386|14|Q2AATX
# 387|14|Q2AA_DAYS
# 388|14|Q2ABPERIODTYPE
# 389|14|Q2ABTX
# 390|14|Q2AB_DAYS
# 391|14|Q2ACPERIODTYPE
# 392|14|Q2ACTX
# 393|14|Q2AC_DAYS
# 394|14|Q2ADPERIODTYPE
# 395|14|Q2ADTX
# 396|14|Q2AD_DAYS
# 397|14|Q2AEPERIODTYPE
# 398|14|Q2AETX
# 399|14|Q2AE_DAYS
# 400|14|Q2A_1
# 401|14|Q2B1APERIODTYPE
# 402|14|Q2B1ATX
# 403|14|Q2B1A_DAYS
# 404|14|Q2B1BPERIODTYPE
# 405|14|Q2B1BTX
# 406|14|Q2B1B_DAYS
# 407|14|Q2B1CPERIODTYPE
# 408|14|Q2B1CTX
# 409|14|Q2B1C_DAYS
# 410|14|Q2B2
# 411|14|Q2B2APERIODTYPE
# 412|14|Q2B2ATX
# 413|14|Q2B2A_DAYS
# 414|14|Q2B2BPERIODTYPE
# 415|14|Q2B2BTX
# 416|14|Q2B2CPERIODTYPE
# 417|14|Q2B2CTX
# 418|14|Q2B2C_DAYS
# 419|14|Q2B2DPERIODTYPE
# 420|14|Q2B2DTX
# 421|14|Q2B2D_DAYS
# 422|14|Q2B2ETX
# 423|14|Q2C
# 424|14|Q2CTX
# 425|14|Requirements
# 426|14|Result
# 427|14|SENTENCEDATETX
# 428|14|SURNAMETX
# 429|14|TYPEOFOFFENCE
# 430|14|Type_of_Offence
# 431|14|UNIQUE
# 432|14|ccssflag
# 433|14|cpdAmount1
# 434|14|cpdClassctn
# 435|14|cpdCourt
# 436|14|cpdCrest_ID
# 437|14|cpdDob
# 438|14|cpdGender
# 439|14|cpdInitial
# 440|14|cpdResult
# 441|14|cpdSent_Date
# 442|14|cpdSurname
# 443|14|cpdUnique
# 444|14|cpdage
# 445|14|cpdamount1wt
# 446|14|cpdcrttype
# 447|14|cpdflag
# 448|14|cpdform
# 449|14|cpdguilty
# 450|14|cpdmonth
# 451|14|cpdsent
# 452|14|cpdweekday
# 453|14|cpdyear
# 454|14|desc
# 455|14|form_overarching
# 456|14|frequency
# 457|14|lowestscores1
# 458|14|manualintervention
# 459|14|offtyp
# 460|14|offtypdesc
# 461|14|pregp_amount1
# 462|14|result
# 463|14|unique_id
# 464|15|Q1A
# 465|15|Q1DRG
# 466|15|Q1x
# 467|15|Q3
# 468|15|Q4A
# 469|15|Q4B
# 470|15|Q5
# 471|15|Q6
# 472|16|Q1A
# 473|16|Q1ATX
# 474|16|Q1X
# 475|16|Q3
# 476|16|Q4A
# 477|16|Q4B
# 478|16|Q5
# 479|16|Q5TX
# 480|16|Q6
# 481|16|Q6
# 482|16|Q6TX

# %%
variables = sql.read_frame('select * from tblVariables', con)
descriptions = sql.read_frame('select * from tblDescriptionGroups', con)
variables.head()
# Out:
#    ID OriginalORSName        BaseName       FinalName  PrefixID Suffix  \
# 0   1       unique_id       unique_id       unique_id        14   None
# 1   2          UNIQUE          UNIQUE          UNIQUE        14   None
# 2   3          ISSUED          ISSUED          ISSUED        14   None
# 3   4  SENTENCEDATETX  SENTENCEDATETX  SENTENCEDATETX        14   None
# 4   5      CREST_IDTX      CREST_IDTX      CREST_IDTX        14   None
#
#   SuffixCode ORSDescription  GroupDescriptionID  \
# 0       None           None                 463
# 1       None        (blank)                 431
# 2       None     Issue date                 379
# 3       None  Sentence date                 427
# 4       None  Crest case ID                 363
#
#                                               Issues InORSRawDataset
# 0  The unique IDs provided to us (in the UNIQUE f...           False
# 1  The unique IDs provided to us aren't always un...            True
# 2                                               None            True
# 3                                               None            True
# 4                                               None            True

# %%
descriptions.head()
# Out:
#     ID                                        Description
# 0  227                                    Type of offence
# 1  228                                    Type of offence
# 2  229                                   Level of offence
# 3  230                          Q3C: Offence seriousness
# 4  231  Previous convictions, Did the offender have an...

# %%
#Make a table of unique combinations of prefix and basename and description
variableswithdescriptions = variables.merge(descriptions, left_on="GroupDescriptionID", right_on="ID", how="left")
variableswithdescriptions.head()
# Out:
#    ID_x OriginalORSName        BaseName       FinalName  PrefixID Suffix  \
# 0     1       unique_id       unique_id       unique_id        14   None
# 1     2          UNIQUE          UNIQUE          UNIQUE        14   None
# 2     3          ISSUED          ISSUED          ISSUED        14   None
# 3     4  SENTENCEDATETX  SENTENCEDATETX  SENTENCEDATETX        14   None
# 4     5      CREST_IDTX      CREST_IDTX      CREST_IDTX        14   None
#
#   SuffixCode ORSDescription  GroupDescriptionID  \
# 0       None           None                 463
# 1       None        (blank)                 431
# 2       None     Issue date                 379
# 3       None  Sentence date                 427
# 4       None  Crest case ID                 363
#
#                                               Issues InORSRawDataset  ID_y  \
# 0  The unique IDs provided to us (in the UNIQUE f...           False   463
# 1  The unique IDs provided to us aren't always un...            True   431
# 2                                               None            True   379
# 3                                               None            True   427
# 4                                               None            True   363
#
#                                          Description
# 0  Unique_id is a unique identifier for this reco...
# 1          UNIQUE as provided by ORS - Not unique!!!
# 2                                         Issue date
# 3                                      Sentence date
# 4                                      Crest case ID

# %%
#Check that there aren't combiantions of prefix and basename with more than one description
prefixbasegroups = variableswithdescriptions.groupby(['PrefixID', "BaseName", "GroupDescriptionID", "Description"]).size()
prefixbasegroups = prefixbasegroups.reset_index()
prefixbasegroups.rename(columns={0: "numvars"}, inplace=True)
gdid = prefixbasegroups.groupby(["GroupDescriptionID"]).size()
gdid = gdid.reset_index().rename(columns={0: "sizenum"})
gdid[gdid["sizenum"]>1].head()
# Out:
#      GroupDescriptionID  sizenum
# 233                 462        2

# %%
variableswithdescriptions[variableswithdescriptions["GroupDescriptionID"]==462]
# Out:
#      ID_x OriginalORSName BaseName FinalName  PrefixID Suffix SuffixCode  \
# 232   233         ResultA   Result   ResultA        14      A          9
# 233   234         ResultB   Result   ResultB        14      B         10
# 234   235         ResultC   Result   ResultC        14      C         11
# 235   236         ResultD   Result   ResultD        14      D         12
# 236   237         ResultE   Result   ResultE        14      E         13
# 237   238         ResultF   Result   ResultF        14      F         14
# 238   239         ResultG   Result   ResultG        14      G         15
# 239  4528            None   result    result        14   None       None
#
#                                ORSDescription  GroupDescriptionID Issues  \
# 232                 Result#Absolute discharge                 462   None
# 233              Result#Conditional discharge                 462   None
# 234                               Result#Fine                 462   None
# 235                                 Result#CO                 462   None
# 236                                Result#SSO                 462   None
# 237  Result#All custody EXCEPT hospital order                 462   None
# 238           Result#Other AND hospital order                 462   None
# 239                                      None                 462   None
#
#     InORSRawDataset  ID_y                                        Description
# 232            True   462  A field derived from ORS data that contains th...
# 233            True   462  A field derived from ORS data that contains th...
# 234            True   462  A field derived from ORS data that contains th...
# 235            True   462  A field derived from ORS data that contains th...
# 236            True   462  A field derived from ORS data that contains th...
# 237            True   462  A field derived from ORS data that contains th...
# 238            True   462  A field derived from ORS data that contains th...
# 239           False   462  A field derived from ORS data that contains th...
